# %%
import pandas as pd

# %%
excel_data = pd.read_excel("Data 101 YT.xlsx")

# %%
excel_data
# Out:
#     Unnamed: 0         Unnamed: 1 Unnamed: 2                Unnamed: 3  \
# 0          NaN                NaN        NaN                       NaN
# 1          NaN                NaN        NaN                       NaN
# 2          NaN                NaN        NaN                       NaN
# 3          SS#      Employee Name     Salary                Department
# 4    812007524      Abbott, James      68370             Manufacturing
# ..         ...                ...        ...                       ...
# 740  539008717       Wyatt, Kelly      61443        Account Management
# 741  690003892        Yates, Doug      74560             Manufacturing
# 742  463006396       York, Steven      45315        Account Management
# 743  829003742    Young, Benjamin      96410             Manufacturing
# 744  280007597  Zimmerman, Julian     112486  Environmental Compliance
#
#       Unnamed: 4           Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# ...

# %%
excel_data.head()
# Out:
#   Unnamed: 0     Unnamed: 1 Unnamed: 2     Unnamed: 3   Unnamed: 4  \
# 0        NaN            NaN        NaN            NaN          NaN
# 1        NaN            NaN        NaN            NaN          NaN
# 2        NaN            NaN        NaN            NaN          NaN
# 3        SS#  Employee Name     Salary     Department          SS#
# 4  812007524  Abbott, James      68370  Manufacturing  112-00-4171
#
#             Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                  NaN        NaN         NaN         NaN         NaN
# 1                  NaN        NaN         NaN         NaN         NaN
# 2                  NaN        NaN         NaN         NaN         NaN
# 3            Hire Date      Years         NaN         NaN         NaN
# 4  1999-05-25 00:00:00         25         NaN         NaN         NaN
#
#      Unnamed: 10
# 0            NaN
# 1            NaN
# 2            NaN
# 3     Department
# 4  Manufacturing

# %%
excel_data.head(50)
# Out:
#    Unnamed: 0          Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 0         NaN                 NaN        NaN                     NaN
# 1         NaN                 NaN        NaN                     NaN
# 2         NaN                 NaN        NaN                     NaN
# 3         SS#       Employee Name     Salary              Department
# 4   812007524       Abbott, James      68370           Manufacturing
# 5   779004027      Acosta, Robert      55164     Manufacturing Admin
# 6   553006436        Adams, David      55593       Quality Assurance
# 7   115005453     Adkins, Michael      52306         Quality Control
# 8   186000986      Aguilar, Kevin      61979      Account Management
# 9   863009097  Alexander, Charles      85241      Account Management
# 10  584008457       Allen, Thomas      44469         Quality Control
# 11  496000423    Allison, Timothy      99925                Training
# 12  920007636     Alvarado, Sonia     121677      Account Management
# ...

# %%
excel_data.tail()
# Out:
#     Unnamed: 0         Unnamed: 1 Unnamed: 2                Unnamed: 3  \
# 740  539008717       Wyatt, Kelly      61443        Account Management
# 741  690003892        Yates, Doug      74560             Manufacturing
# 742  463006396       York, Steven      45315        Account Management
# 743  829003742    Young, Benjamin      96410             Manufacturing
# 744  280007597  Zimmerman, Julian     112486  Environmental Compliance
#
#       Unnamed: 4           Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 740  994-00-5178  2006-04-08 00:00:00         18         NaN         NaN
# 741  997-00-0797  2010-05-14 00:00:00         14         NaN         NaN
# 742  998-00-2689  2010-03-22 00:00:00         14         NaN         NaN
# 743  998-00-2619  1998-07-20 00:00:00         26         NaN         NaN
# 744  999-00-2126  2007-11-28 00:00:00         17         NaN         NaN
#
#      Unnamed: 9 Unnamed: 10
# 740         NaN         NaN
# 741         NaN         NaN
# ...

# %%
excel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   742 non-null    object
#  1   Unnamed: 1   742 non-null    object
#  2   Unnamed: 2   742 non-null    object
#  3   Unnamed: 3   742 non-null    object
#  4   Unnamed: 4   742 non-null    object
#  5   Unnamed: 5   742 non-null    object
#  6   Unnamed: 6   742 non-null    object
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  22 non-null     object
# dtypes: float64(3), object(8)
# memory usage: 64.2+ KB

# %%
excel_data.describe(include='all')
# Out:
#          Unnamed: 0         Unnamed: 1  Unnamed: 2     Unnamed: 3  \
# count         742.0                742       742.0            742
# unique        742.0                742       741.0             22
# top     280007597.0  Zimmerman, Julian     45315.0  Manufacturing
# freq            1.0                  1         2.0            151
# mean            NaN                NaN         NaN            NaN
# std             NaN                NaN         NaN            NaN
# min             NaN                NaN         NaN            NaN
# 25%             NaN                NaN         NaN            NaN
# 50%             NaN                NaN         NaN            NaN
# 75%             NaN                NaN         NaN            NaN
# max             NaN                NaN         NaN            NaN
#
#          Unnamed: 4           Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# count           742                  742       742.0         0.0         0.0
# ...

# %% [markdown]
# ### Data Cleaning

# %%
excel_data.drop( [0,1,2],inplace = True)

# %%
excel_data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')

# %%
excel_data.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
       'Unnamed: 10'],axis=1,inplace=True)

# %%
excel_data
# Out:
#     Unnamed: 0         Unnamed: 1 Unnamed: 2                Unnamed: 3  \
# 3          SS#      Employee Name     Salary                Department
# 4    812007524      Abbott, James      68370             Manufacturing
# 5    779004027     Acosta, Robert      55164       Manufacturing Admin
# 6    553006436       Adams, David      55593         Quality Assurance
# 7    115005453    Adkins, Michael      52306           Quality Control
# ..         ...                ...        ...                       ...
# 740  539008717       Wyatt, Kelly      61443        Account Management
# 741  690003892        Yates, Doug      74560             Manufacturing
# 742  463006396       York, Steven      45315        Account Management
# 743  829003742    Young, Benjamin      96410             Manufacturing
# 744  280007597  Zimmerman, Julian     112486  Environmental Compliance
#
#       Unnamed: 4           Unnamed: 5 Unnamed: 6
# 3            SS#            Hire Date      Years
# ...

# %% [raw]
# # to make reference to a row, we can use
# # data.loc[.....uses label
# # data.ilocl[....uses index

# %%
excel_data.loc[3]
# Out:
# Unnamed: 0              SS#
# Unnamed: 1    Employee Name
# Unnamed: 2           Salary
# Unnamed: 3       Department
# Unnamed: 4              SS#
# Unnamed: 5        Hire Date
# Unnamed: 6            Years
# Name: 3, dtype: object

# %%
excel_data.loc[3:9]
# Out:
#   Unnamed: 0          Unnamed: 1 Unnamed: 2           Unnamed: 3   Unnamed: 4  \
# 3        SS#       Employee Name     Salary           Department          SS#
# 4  812007524       Abbott, James      68370        Manufacturing  112-00-4171
# 5  779004027      Acosta, Robert      55164  Manufacturing Admin  114-00-0990
# 6  553006436        Adams, David      55593    Quality Assurance  115-00-5453
# 7  115005453     Adkins, Michael      52306      Quality Control  116-00-2393
# 8  186000986      Aguilar, Kevin      61979   Account Management  117-00-3143
# 9  863009097  Alexander, Charles      85241   Account Management  118-00-6304
#
#             Unnamed: 5 Unnamed: 6
# 3            Hire Date      Years
# 4  1999-05-25 00:00:00         25
# 5  2010-05-15 00:00:00         14
# 6  2010-11-04 00:00:00         14
# 7  2007-07-20 00:00:00         17
# 8  2011-12-01 00:00:00         13
# 9  2002-09-27 00:00:00         22

# %%
excel_data.iloc[1:7]
# Out:
#   Unnamed: 0          Unnamed: 1 Unnamed: 2           Unnamed: 3   Unnamed: 4  \
# 4  812007524       Abbott, James      68370        Manufacturing  112-00-4171
# 5  779004027      Acosta, Robert      55164  Manufacturing Admin  114-00-0990
# 6  553006436        Adams, David      55593    Quality Assurance  115-00-5453
# 7  115005453     Adkins, Michael      52306      Quality Control  116-00-2393
# 8  186000986      Aguilar, Kevin      61979   Account Management  117-00-3143
# 9  863009097  Alexander, Charles      85241   Account Management  118-00-6304
#
#             Unnamed: 5 Unnamed: 6
# 4  1999-05-25 00:00:00         25
# 5  2010-05-15 00:00:00         14
# 6  2010-11-04 00:00:00         14
# 7  2007-07-20 00:00:00         17
# 8  2011-12-01 00:00:00         13
# 9  2002-09-27 00:00:00         22

# %% [raw]
# # to make reference to columns
# data['column

# %%
excel_data[['Unnamed: 1', 'Unnamed: 2',	'Unnamed: 3']]
# Out:
#             Unnamed: 1 Unnamed: 2                Unnamed: 3
# 3        Employee Name     Salary                Department
# 4        Abbott, James      68370             Manufacturing
# 5       Acosta, Robert      55164       Manufacturing Admin
# 6         Adams, David      55593         Quality Assurance
# 7      Adkins, Michael      52306           Quality Control
# ..                 ...        ...                       ...
# 740       Wyatt, Kelly      61443        Account Management
# 741        Yates, Doug      74560             Manufacturing
# 742       York, Steven      45315        Account Management
# 743    Young, Benjamin      96410             Manufacturing
# 744  Zimmerman, Julian     112486  Environmental Compliance
#
# [742 rows x 3 columns]

# %%
excel_data.loc [5,'Unnamed: 1'] = 'Career Insight'

# %%
excel_data
# Out:
#     Unnamed: 0         Unnamed: 1 Unnamed: 2                Unnamed: 3  \
# 3          SS#      Employee Name     Salary                Department
# 4    812007524      Abbott, James      68370             Manufacturing
# 5    779004027     Career Insight      55164       Manufacturing Admin
# 6    553006436       Adams, David      55593         Quality Assurance
# 7    115005453    Adkins, Michael      52306           Quality Control
# ..         ...                ...        ...                       ...
# 740  539008717       Wyatt, Kelly      61443        Account Management
# 741  690003892        Yates, Doug      74560             Manufacturing
# 742  463006396       York, Steven      45315        Account Management
# 743  829003742    Young, Benjamin      96410             Manufacturing
# 744  280007597  Zimmerman, Julian     112486  Environmental Compliance
#
#       Unnamed: 4           Unnamed: 5 Unnamed: 6
# 3            SS#            Hire Date      Years
# ...

# %%
excel_data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
excel_data.loc[3]
# Out:
# Unnamed: 0              SS#
# Unnamed: 1    Employee Name
# Unnamed: 2           Salary
# Unnamed: 3       Department
# Unnamed: 4              SS#
# Unnamed: 5        Hire Date
# Unnamed: 6            Years
# Name: 3, dtype: object

# %%
excel_data.columns = excel_data.loc[3]

# %%
excel_data
# Out:
# 3          SS#      Employee Name  Salary                Department  \
# 3          SS#      Employee Name  Salary                Department
# 4    812007524      Abbott, James   68370             Manufacturing
# 5    779004027     Career Insight   55164       Manufacturing Admin
# 6    553006436       Adams, David   55593         Quality Assurance
# 7    115005453    Adkins, Michael   52306           Quality Control
# ..         ...                ...     ...                       ...
# 740  539008717       Wyatt, Kelly   61443        Account Management
# 741  690003892        Yates, Doug   74560             Manufacturing
# 742  463006396       York, Steven   45315        Account Management
# 743  829003742    Young, Benjamin   96410             Manufacturing
# 744  280007597  Zimmerman, Julian  112486  Environmental Compliance
#
# 3            SS#            Hire Date  Years
# 3            SS#            Hire Date  Years
# 4    112-00-4171  1999-05-25 00:00:00     25
# ...

# %%
excel_data.drop(3,inplace=True)

# %%
excel_data
# Out:
# 3          SS#      Employee Name  Salary                Department  \
# 4    812007524      Abbott, James   68370             Manufacturing
# 5    779004027     Career Insight   55164       Manufacturing Admin
# 6    553006436       Adams, David   55593         Quality Assurance
# 7    115005453    Adkins, Michael   52306           Quality Control
# 8    186000986     Aguilar, Kevin   61979        Account Management
# ..         ...                ...     ...                       ...
# 740  539008717       Wyatt, Kelly   61443        Account Management
# 741  690003892        Yates, Doug   74560             Manufacturing
# 742  463006396       York, Steven   45315        Account Management
# 743  829003742    Young, Benjamin   96410             Manufacturing
# 744  280007597  Zimmerman, Julian  112486  Environmental Compliance
#
# 3            SS#            Hire Date Years
# 4    112-00-4171  1999-05-25 00:00:00    25
# 5    114-00-0990  2010-05-15 00:00:00    14
# ...

# %%
excel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 4 to 744
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SS#            741 non-null    object
#  1   Employee Name  741 non-null    object
#  2   Salary         741 non-null    object
#  3   Department     741 non-null    object
#  4   SS#            741 non-null    object
#  5   Hire Date      741 non-null    object
#  6   Years          741 non-null    object
# dtypes: object(7)
# memory usage: 40.7+ KB

# %%
excel_data.describe()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13632\1547831755.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   excel_data.describe()
# 3             SS#      Employee Name  Salary     Department          SS#  \
# count         741                741     741            741          741
# unique        741                741     740             21          741
# top     280007597  Zimmerman, Julian   45315  Manufacturing  999-00-2126
# freq            1                  1       2            151            1
#
# 3                 Hire Date  Years
# count                   741    741
# unique                  674     16
# top     1998-10-16 00:00:00     14
# freq                      3     98

# %% [markdown]
# ### Data Type Conversion

# %% [markdown]
# # making reference to column

# %%
excel_data['Employee Name']
# Out:
# 4          Abbott, James
# 5         Career Insight
# 6           Adams, David
# 7        Adkins, Michael
# 8         Aguilar, Kevin
#              ...
# 740         Wyatt, Kelly
# 741          Yates, Doug
# 742         York, Steven
# 743      Young, Benjamin
# 744    Zimmerman, Julian
# Name: Employee Name, Length: 741, dtype: object

# %%
excel_data[['Employee Name','Years','Salary']]
# Out:
# 3        Employee Name Years  Salary
# 4        Abbott, James    25   68370
# 5       Career Insight    14   55164
# 6         Adams, David    14   55593
# 7      Adkins, Michael    17   52306
# 8       Aguilar, Kevin    13   61979
# ..                 ...   ...     ...
# 740       Wyatt, Kelly    18   61443
# 741        Yates, Doug    14   74560
# 742       York, Steven    14   45315
# 743    Young, Benjamin    26   96410
# 744  Zimmerman, Julian    17  112486
#
# [741 rows x 3 columns]

# %%
# Making reference to rows

# %%
excel_data.loc[8]
# Out:
# 3
# SS#                        186000986
# Employee Name         Aguilar, Kevin
# Salary                         61979
# Department        Account Management
# SS#                      117-00-3143
# Hire Date        2011-12-01 00:00:00
# Years                             13
# Name: 8, dtype: object

# %%
# Or

# %%
excel_data.iloc[4]
# Out:
# 3
# SS#                        186000986
# Employee Name         Aguilar, Kevin
# Salary                         61979
# Department        Account Management
# SS#                      117-00-3143
# Hire Date        2011-12-01 00:00:00
# Years                             13
# Name: 8, dtype: object

# %%
excel_data.loc[5:8]
# Out:
# 3        SS#    Employee Name Salary           Department          SS#  \
# 5  779004027   Career Insight  55164  Manufacturing Admin  114-00-0990
# 6  553006436     Adams, David  55593    Quality Assurance  115-00-5453
# 7  115005453  Adkins, Michael  52306      Quality Control  116-00-2393
# 8  186000986   Aguilar, Kevin  61979   Account Management  117-00-3143
#
# 3            Hire Date Years
# 5  2010-05-15 00:00:00    14
# 6  2010-11-04 00:00:00    14
# 7  2007-07-20 00:00:00    17
# 8  2011-12-01 00:00:00    13

# %%
excel_data.loc[5:8, 'Salary']
# Out:
# 5    55164
# 6    55593
# 7    52306
# 8    61979
# Name: Salary, dtype: object

# %%
excel_data[['Years','Salary']].astype(int)
# Out:
# 3    Years  Salary
# 4       25   68370
# 5       14   55164
# 6       14   55593
# 7       17   52306
# 8       13   61979
# ..     ...     ...
# 740     18   61443
# 741     14   74560
# 742     14   45315
# 743     26   96410
# 744     17  112486
#
# [741 rows x 2 columns]

# %%
excel_data['Years'].astype(int)
# Out:
# 4      25
# 5      14
# 6      14
# 7      17
# 8      13
#        ..
# 740    18
# 741    14
# 742    14
# 743    26
# 744    17
# Name: Years, Length: 741, dtype: int64

# %%
excel_data['Years']
# Out:
# 4      25
# 5      14
# 6      14
# 7      17
# 8      13
#        ..
# 740    18
# 741    14
# 742    14
# 743    26
# 744    17
# Name: Years, Length: 741, dtype: object

# %%
excel_data['Years'] = excel_data['Years'].astype(int)

# %%
excel_data[['Years','Salary']] = excel_data[['Years','Salary']].astype(int)

# %%
pd.to_datetime(excel_data['Hire Date'])
# Out:
# 4     1999-05-25
# 5     2010-05-15
# 6     2010-11-04
# 7     2007-07-20
# 8     2011-12-01
#          ...
# 740   2006-04-08
# 741   2010-05-14
# 742   2010-03-22
# 743   1998-07-20
# 744   2007-11-28
# Name: Hire Date, Length: 741, dtype: datetime64[ns]

# %%
excel_data['Hire Date']=pd.to_datetime(excel_data['Hire Date'])

# %%
excel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 4 to 744
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SS#            741 non-null    object
#  1   Employee Name  741 non-null    object
#  2   Salary         741 non-null    int64
#  3   Department     741 non-null    object
#  4   SS#            741 non-null    object
#  5   Hire Date      741 non-null    datetime64[ns]
#  6   Years          741 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 40.7+ KB

# %%
excel_data.describe()
# Out:
# 3             Salary                   Hire Date       Years
# count     741.000000                         741  741.000000
# mean    82742.639676  2006-03-30 14:11:10.445344   18.203779
# min     42001.000000         1998-01-06 00:00:00   11.000000
# 25%     60764.000000         2001-07-10 00:00:00   14.000000
# 50%     81413.000000         2007-05-06 00:00:00   17.000000
# 75%    104133.000000         2010-05-22 00:00:00   23.000000
# max    126954.000000         2012-12-19 00:00:00   26.000000
# std     24929.357122                         NaN    4.652844

# %%
excel_data.describe(include='all')
# Out:
# 3               SS#      Employee Name         Salary     Department  \
# count         741.0                741     741.000000            741
# unique        741.0                741            NaN             21
# top     280007597.0  Zimmerman, Julian            NaN  Manufacturing
# freq            1.0                  1            NaN            151
# mean            NaN                NaN   82742.639676            NaN
# min             NaN                NaN   42001.000000            NaN
# 25%             NaN                NaN   60764.000000            NaN
# 50%             NaN                NaN   81413.000000            NaN
# 75%             NaN                NaN  104133.000000            NaN
# max             NaN                NaN  126954.000000            NaN
# std             NaN                NaN   24929.357122            NaN
#
# 3               SS#                   Hire Date       Years
# count           741                         741  741.000000
# ...

# %%
excel_data.sort_values('Salary')
# Out:
# 3          SS#       Employee Name  Salary              Department  \
# 369  707000901      Knight, Denise   42001      Account Management
# 193  319005817     Erickson, Ricky   42102                Creative
# 105  561003247   Campbell, Michael   42273                     ADC
# 138  781005646       Collier, Dean   42407           Manufacturing
# 63   203004099          Bond, John   42446                Training
# ..         ...                 ...     ...                     ...
# 276  920009263  Hampton, Catherine  126555  Facilities/Engineering
# 563  585009908      Rhodes, Brenda  126627         Quality Control
# 362  679007007         Kent, Angus  126756      Account Management
# 726  518009982     Williams, Scott  126925  Facilities/Engineering
# 499  714000417         Olsen, Ewan  126954           Manufacturing
#
# 3            SS#  Hire Date  Years
# 369  567-00-3511 2008-08-13     16
# 193  368-00-9712 1998-06-13     26
# 105  247-00-3062 1999-01-11     25
# ...

# %%
excel_data.sort_values('Salary',ascending=False)
# Out:
# 3          SS#       Employee Name  Salary              Department  \
# 499  714000417         Olsen, Ewan  126954           Manufacturing
# 726  518009982     Williams, Scott  126925  Facilities/Engineering
# 362  679007007         Kent, Angus  126756      Account Management
# 563  585009908      Rhodes, Brenda  126627         Quality Control
# 276  920009263  Hampton, Catherine  126555  Facilities/Engineering
# ..         ...                 ...     ...                     ...
# 63   203004099          Bond, John   42446                Training
# 138  781005646       Collier, Dean   42407           Manufacturing
# 105  561003247   Campbell, Michael   42273                     ADC
# 193  319005817     Erickson, Ricky   42102                Creative
# 369  707000901      Knight, Denise   42001      Account Management
#
# 3            SS#  Hire Date  Years
# 499  724-00-7373 1999-01-17     25
# 726  982-00-0179 2006-08-25     18
# 362  561-00-3247 2000-09-18     24
# ...

# %%
excel_data.sort_values('Employee Name',ascending=False)
# Out:
# 3          SS#       Employee Name  Salary                Department  \
# 744  280007597   Zimmerman, Julian  112486  Environmental Compliance
# 743  829003742     Young, Benjamin   96410             Manufacturing
# 742  463006396        York, Steven   45315        Account Management
# 741  690003892         Yates, Doug   74560             Manufacturing
# 740  539008717        Wyatt, Kelly   61443        Account Management
# ..         ...                 ...     ...                       ...
# 9    863009097  Alexander, Charles   85241        Account Management
# 8    186000986      Aguilar, Kevin   61979        Account Management
# 7    115005453     Adkins, Michael   52306           Quality Control
# 6    553006436        Adams, David   55593         Quality Assurance
# 4    812007524       Abbott, James   68370             Manufacturing
#
# 3            SS#  Hire Date  Years
# 744  999-00-2126 2007-11-28     17
# 743  998-00-2619 1998-07-20     26
# ...

# %%
excel_data.sort_values('Years')
# Out:
# 3          SS#       Employee Name  Salary              Department  \
# 228  935000539      Gaines, Sheela   80600         Quality Control
# 39   568005143     Bartlett, Julia   53431               Marketing
# 310  427007916         Hines, Herb   64749       Quality Assurance
# 38   296001755     Barron, Michael   45843                      IT
# 65   530002235         Boone, Eric   88499           Manufacturing
# ..         ...                 ...     ...                     ...
# 720  445009708      Wilcox, Robert  100248           Manufacturing
# 722  845000798  Wilkerson, Claudia  121824         Quality Control
# 698  971003702         Ware, David   60730  Facilities/Engineering
# 49   985001341    Becker, Gretchen   71321  Facilities/Engineering
# 340  558005492        Ingram, Matt   55409     Product Development
#
# 3            SS#  Hire Date  Years
# 228  410-00-3795 2012-12-19     11
# 39   161-00-0365 2012-04-08     12
# 310  501-00-3738 2012-11-06     12
# ...

# %%
excel_data.sort_values(['Employee Name','Department'], ascending=False)
# Out:
# 3          SS#       Employee Name  Salary                Department  \
# 744  280007597   Zimmerman, Julian  112486  Environmental Compliance
# 743  829003742     Young, Benjamin   96410             Manufacturing
# 742  463006396        York, Steven   45315        Account Management
# 741  690003892         Yates, Doug   74560             Manufacturing
# 740  539008717        Wyatt, Kelly   61443        Account Management
# ..         ...                 ...     ...                       ...
# 9    863009097  Alexander, Charles   85241        Account Management
# 8    186000986      Aguilar, Kevin   61979        Account Management
# 7    115005453     Adkins, Michael   52306           Quality Control
# 6    553006436        Adams, David   55593         Quality Assurance
# 4    812007524       Abbott, James   68370             Manufacturing
#
# 3            SS#  Hire Date  Years
# 744  999-00-2126 2007-11-28     17
# 743  998-00-2619 1998-07-20     26
# ...

# %%
# to get top 10

# %%
excel_data.sort_values(['Employee Name','Department'], ascending=False).head(10)
# Out:
# 3          SS#      Employee Name  Salary                Department  \
# 744  280007597  Zimmerman, Julian  112486  Environmental Compliance
# 743  829003742    Young, Benjamin   96410             Manufacturing
# 742  463006396       York, Steven   45315        Account Management
# 741  690003892        Yates, Doug   74560             Manufacturing
# 740  539008717       Wyatt, Kelly   61443        Account Management
# 739  368000382       Wright, Brad   60725                     Sales
# 738  648005012      Woodward, Tim   63297       Manufacturing Admin
# 737  495002073      Woods, Marcus  109943        Major Mfg Projects
# 736  114000990   Woodard, Charles   61640                 Marketing
# 735  993006935        Wood, Larry  103260    Facilities/Engineering
#
# 3            SS#  Hire Date  Years
# 744  999-00-2126 2007-11-28     17
# 743  998-00-2619 1998-07-20     26
# 742  998-00-2689 2010-03-22     14
# 741  997-00-0797 2010-05-14     14
# 740  994-00-5178 2006-04-08     18
# ...

# %%
# or

# %%
excel_data.sort_values(['Employee Name','Department'], ascending=False)[0:10]
# Out:
# 3          SS#      Employee Name  Salary                Department  \
# 744  280007597  Zimmerman, Julian  112486  Environmental Compliance
# 743  829003742    Young, Benjamin   96410             Manufacturing
# 742  463006396       York, Steven   45315        Account Management
# 741  690003892        Yates, Doug   74560             Manufacturing
# 740  539008717       Wyatt, Kelly   61443        Account Management
# 739  368000382       Wright, Brad   60725                     Sales
# 738  648005012      Woodward, Tim   63297       Manufacturing Admin
# 737  495002073      Woods, Marcus  109943        Major Mfg Projects
# 736  114000990   Woodard, Charles   61640                 Marketing
# 735  993006935        Wood, Larry  103260    Facilities/Engineering
#
# 3            SS#  Hire Date  Years
# 744  999-00-2126 2007-11-28     17
# 743  998-00-2619 1998-07-20     26
# 742  998-00-2689 2010-03-22     14
# 741  997-00-0797 2010-05-14     14
# 740  994-00-5178 2006-04-08     18
# ...

# %% [markdown]
# ### Filtering

# %%
# Get all FullTime Employees

excel_data ['Department'] == 'Manufacturing'
# assign FT to the excel_data (it could actually be anything)
FT = excel_data ['Department'] == 'Manufacturing'
excel_data[FT]
# Out:
# 3          SS#     Employee Name  Salary     Department          SS#  \
# 4    812007524     Abbott, James   68370  Manufacturing  112-00-4171
# 16   934001666   Anthony, Robert  101020  Manufacturing  125-00-3650
# 17   795008732  Armstrong, David  117406  Manufacturing  132-00-4327
# 23   441009754       Avila, Jody   60907  Manufacturing  134-00-5270
# 26   246001186    Bailey, Victor   84936  Manufacturing  138-00-0535
# ..         ...               ...     ...            ...          ...
# 719  950000069    Wiggins, Frank  113020  Manufacturing  970-00-3354
# 720  445009708    Wilcox, Robert  100248  Manufacturing  970-00-7327
# 728  277002530     Willis, Ralph   43394  Manufacturing  984-00-7817
# 741  690003892       Yates, Doug   74560  Manufacturing  997-00-0797
# 743  829003742   Young, Benjamin   96410  Manufacturing  998-00-2619
#
# 3    Hire Date  Years
# 4   1999-05-25     25
# 16  2008-12-03     16
# 17  2007-07-01     17
# 23  1998-11-23     26
# ...

# %%
excel_data['Department']
excel_data['Department']=='Marketing'
Marketing=excel_data['Department']=='Marketing'
excel_data[Marketing]
# Out:
# 3          SS#       Employee Name  Salary Department          SS#  Hire Date  \
# 27   895002504       Baker, Barney  104593  Marketing  144-00-8966 2007-03-16
# 28   933009458        Baldwin, Ray   65190  Marketing  145-00-4331 2009-02-27
# 33   788007684       Barker, Heidi   47765  Marketing  154-00-5819 2011-06-18
# 37   544002285       Barrett, John  122418  Marketing  159-00-3488 2012-01-03
# 39   568005143     Bartlett, Julia   53431  Marketing  161-00-0365 2012-04-08
# 69   599000074     Bowman, Michael   54271  Marketing  196-00-5175 2009-09-27
# 77   504003033        Brewer, Kent   97544  Marketing  203-00-4099 2010-08-05
# 82   465009876       Brown, Donald   81413  Marketing  216-00-7289 2007-07-20
# 95   929006127          Bush, Rena   45419  Marketing  235-00-4630 2001-09-07
# 98   559002062           Cabe, Max   75506  Marketing  237-00-7469 1999-10-23
# 103  798009136  Camacho, Stephanie  108167  Marketing  245-00-3070 2007-03-26
# ...

# %%
Yrs=excel_data['Years'] > 20
excel_data[Yrs]
# Out:
# 3          SS#       Employee Name  Salary              Department  \
# 4    812007524       Abbott, James   68370           Manufacturing
# 9    863009097  Alexander, Charles   85241      Account Management
# 10   584008457       Allen, Thomas   44469         Quality Control
# 12   920007636     Alvarado, Sonia  121677      Account Management
# 20   769008387       Atkins, Kevin   55792      Account Management
# ..         ...                 ...     ...                     ...
# 735  993006935         Wood, Larry  103260  Facilities/Engineering
# 736  114000990    Woodard, Charles   61640               Marketing
# 737  495002073       Woods, Marcus  109943      Major Mfg Projects
# 738  648005012       Woodward, Tim   63297     Manufacturing Admin
# 743  829003742     Young, Benjamin   96410           Manufacturing
#
# 3            SS#  Hire Date  Years
# 4    112-00-4171 1999-05-25     25
# 9    118-00-6304 2002-09-27     22
# 10   119-00-4638 2001-01-27     23
# ...

# %%
# can even sort
excel_data[Yrs].sort_values(by='Salary',ascending=False).head(10)
# Out:
# 3          SS#       Employee Name  Salary              Department  \
# 499  714000417         Olsen, Ewan  126954           Manufacturing
# 362  679007007         Kent, Angus  126756      Account Management
# 276  920009263  Hampton, Catherine  126555  Facilities/Engineering
# 388  801002488      Lester, Sherri  125922     Manufacturing Admin
# 734  298001737        Wong, Dennis  125668       Quality Assurance
# 329  455003707     Hubbard, Sandra  125113                Training
# 533  392005739    Phelps, Gretchen  124798               Marketing
# 90   526005485     Burgess, Cherie  124698           Manufacturing
# 658  342008179    Sweeney, Barbara  124666         Quality Control
# 173  895002812  Dickerson, Lincoln  123134         Quality Control
#
# 3            SS#  Hire Date  Years
# 499  724-00-7373 1999-01-17     25
# 362  561-00-3247 2000-09-18     24
# 276  459-00-3811 1998-05-25     26
# 388  584-00-8457 2000-08-27     24
# 734  989-00-7527 1998-02-16     26
# ...

# %%
# for multiple condition
Marketing=excel_data['Department']=='Marketing'
Yrs=excel_data['Years']>20
Salary=excel_data['Salary']>10000
HD=excel_data['Hire Date']>'1992-12-31'
data = excel_data[Marketing & Yrs & Salary & HD].head(10)

# %%
data
# Out:
# 3          SS#      Employee Name  Salary Department          SS#  Hire Date  \
# 95   929006127         Bush, Rena   45419  Marketing  235-00-4630 2001-09-07
# 98   559002062          Cabe, Max   75506  Marketing  237-00-7469 1999-10-23
# 107  196008245      Cannon, Jenny   79741  Marketing  249-00-6642 2000-06-26
# 162  339008975    Davenport, Troy   69179  Marketing  324-00-6819 2001-02-18
# 169  666007784   Deleon, Jaquelyn   74177  Marketing  330-00-4895 1998-12-16
# 303  464009886     Herrera, Shawn  115240  Marketing  496-00-7469 1998-03-02
# 345  796005096     Jenkins, Scott  108854  Marketing  543-00-5811 1999-05-17
# 346  983006861     Jennings, Gary   83609  Marketing  544-00-2285 1998-11-17
# 434  808003622    McDowell, Scott  120696  Marketing  644-00-0811 2000-05-16
# 459  727003353  Montgomery, Chris  114029  Marketing  683-00-3709 2001-09-04
#
# 3    Years
# 95      23
# 98      25
# 107     24
# 162     23
# 169     26
# 303     26
# 345     25
# 346     26
# ...

# %%
A=excel_data['Employee Name'].str.startswith('A')
Marketing=excel_data['Department']=='Marketing'
Manufacturing=excel_data['Department']=='Manufacturing'

# %% [markdown]
# ### Appending

# %%
# append combines data by stacking data by role

# %%
# data for appending

# %%
Jan = pd.read_table('Jan2015Sales.txt')

# %%
Feb = pd.read_table('Feb2015Sales.txt')

# %%
Mar = pd.read_table('Mar2015Sales.txt')

# %%
Apr = pd.read_table('April2015Sales.txt')

# %%
May = pd.read_table('May2015Sales.txt')

# %%
Nov = pd.read_table('Nov2015Sales.txt')

# %%
Dec = pd.read_table('Dec2015Sales.txt')

# %%
# data for merging

# %%
Sales = pd.read_excel('Adventure_database.xlsx',3)

# %%
Adw = pd.read_excel('AdventureWorks_Database - Copy.xlsx')

# %%
Territory = pd.read_excel('Adventure_database.xlsx',4)

# %% [markdown]
# ##### Append

# %%
monthly_sales = pd.concat([Jan, Feb, Mar, Apr, May, Nov, Dec])

# %% [markdown]
# ##### Merge

# %%
merge_data = Sales.merge(Territory,on='SalesTerritoryKey')

# %%
monthly_sales.head(50)
# Out:
#     Year     Month           Type Salesperson   Region       Sales   Units  \
# 0   2015   January      Ice Cream      Bishop     West    2,395.50    1597
# 1   2015   January      Ice Cream      Bishop     West   11,761.50    7841
# 2   2015   January  Frozen Yogurt      Bishop     West    8,943.00    5962
# 3   2015   January      Ice Cream      Bishop     West    2,395.50    1597
# 4   2015   January      Ice Cream      Bishop     West   11,761.50    7841
# 5   2015   January  Frozen Yogurt      Bishop     West    8,943.00    5962
# 6   2015   January  Frozen Yogurt         Lee  Central   14,596.50    9731
# 7   2015   January   Tasty Treats         Lee  Central    8,793.00    5862
# 8   2015   January  Frozen Yogurt         Lee  Central   14,596.50    9731
# 9   2015   January   Tasty Treats         Lee  Central    8,793.00    5862
# 10  2015   January      Ice Cream      Parker    North    4,666.00    5623
# ...

# %%
monthly_sales.describe()
# Out:
#          Year        Units     Order #
# count   148.0   148.000000  148.000000
# mean   2015.0  5231.067568  370.500000
# std       0.0  2827.602279   42.868014
# min    2015.0   157.000000  297.000000
# 25%    2015.0  2598.000000  333.750000
# 50%    2015.0  4896.000000  370.500000
# 75%    2015.0  7841.000000  407.250000
# max    2015.0  9765.000000  444.000000

# %%
monthly_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, 0 to 17
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         148 non-null    int64
#  1   Month        148 non-null    object
#  2   Type         148 non-null    object
#  3   Salesperson  148 non-null    object
#  4   Region       148 non-null    object
#  5    Sales       148 non-null    object
#  6   Units        148 non-null    int64
#  7   Order #      148 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 10.4+ KB

# %%
monthly_sales.columns
# Out:
# Index(['Year', 'Month', 'Type', 'Salesperson', 'Region', ' Sales ', 'Units',
#        'Order #'],
#       dtype='object')

# %%
monthly_sales.columns.str.strip()
monthly_sales.columns = monthly_sales.columns.str.strip()

# %%
# this is how to convert though....monthly_sales['Sales'].astype(int)

# %%
monthly_sales['Sales'].str.replace(',','').astype(float)
monthly_sales['Sales'].str.replace(',','').astype(float).round()
monthly_sales['Sales'] =monthly_sales['Sales'].str.replace(',','').astype(float).astype(int)

# %%
monthly_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, 0 to 17
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         148 non-null    int64
#  1   Month        148 non-null    object
#  2   Type         148 non-null    object
#  3   Salesperson  148 non-null    object
#  4   Region       148 non-null    object
#  5   Sales        148 non-null    int64
#  6   Units        148 non-null    int64
#  7   Order #      148 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 10.4+ KB

# %% [markdown]
# ### Group BY

# %%
monthly_sales.groupby(by='Region')['Sales'].sum()
# Out:
# Region
# Central    483102
# North      269716
# South      180360
# West       205474
# Name: Sales, dtype: int64

# %%
monthly_sales.groupby(by='Region')['Sales'].count()
# Out:
# Region
# Central    56
# North      34
# South      28
# West       30
# Name: Sales, dtype: int64

# %%
monthly_sales.groupby(by='Region')['Sales'].max()
# Out:
# Region
# Central    14619
# North      14619
# South      14647
# West       14619
# Name: Sales, dtype: int64

# %%
monthly_sales.groupby(by='Region',as_index=False)['Sales'].sum()
# Out:
#     Region   Sales
# 0  Central  483102
# 1    North  269716
# 2    South  180360
# 3     West  205474

# %%
monthly_sales.groupby(by=['Salesperson','Month'],as_index=False)['Sales'].sum()
# Out:
#    Salesperson     Month   Sales
# 0       Bishop     April   18494
# 1       Bishop  December   52542
# 2       Bishop  February    9774
# 3       Bishop   January   46198
# 4       Bishop     March   30972
# 5       Bishop       May   16178
# 6       Bishop  November   31316
# 7          Lee     April   46562
# 8          Lee  December   24758
# 9          Lee  February   49100
# 10         Lee   January   46778
# 11         Lee     March   39998
# 12         Lee       May   28448
# 13         Lee  November   17126
# 14      Parker     April  100658
# 15      Parker  December   33656
# 16      Parker  February   25458
# 17      Parker   January   23968
# 18      Parker     March   36286
# 19      Parker       May   34436
# 20      Parker  November   15254
# 21      Pullen     April   47634
# 22      Pullen  December   13570
# 23      Pullen  February   51538
# 24      Pullen   January    7106
# 25      Pullen     March    3466
# 26      Pullen       May   43084
# ...

# %%
pd.pivot_table(monthly_sales,'Sales','Type','Salesperson','sum')
# Out:
# Salesperson    Bishop    Lee  Parker  Pullen  Watson
# Type
# Frozen Yogurt   37044  58742   56144   40084   33284
# Ice Cream       97962  98444  104232   82506   97110
# Popsicles       27470  19422   19418   27962   43852
# Tasty Treats    42998  76162   89922   29808   56086

# %%
pd.pivot_table(monthly_sales,'Sales','Type','Salesperson','count')
# Out:
# Salesperson    Bishop  Lee  Parker  Pullen  Watson
# Type
# Frozen Yogurt       6    8       8       6       4
# Ice Cream          14   12      12      10      10
# Popsicles           6    4       4       6       4
# Tasty Treats        4    8      10       6       6

# %%
Analyt=pd.pivot_table(monthly_sales,'Sales','Type','Salesperson')

# %%
import seaborn as sns

# %%
sns.heatmap(Analyt)
# Out:
# <Axes: xlabel='Salesperson', ylabel='Type'>

# %%
sns.heatmap(pd.pivot_table(monthly_sales,'Sales','Type','Salesperson','count'),annot=True)
# Out:
# <Axes: xlabel='Salesperson', ylabel='Type'>

# %% [markdown]
# ### Libraries

# %%
# Matplolip Data visualization like bar chart

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
monthly_sales
excel_data
Sales
# Out:
#        ProductKey  OrderDate   ShipDate  CustomerKey  PromotionKey  \
# 0             310 2014-01-01 2014-01-08        21768             1
# 1             346 2014-01-01 2014-01-08        28389             1
# 2             346 2014-01-01 2014-01-08        25863             1
# 3             336 2014-01-01 2014-01-08        14501             1
# 4             346 2014-01-01 2014-01-08        11003             1
# ...           ...        ...        ...          ...           ...
# 58184         561 2016-12-30 2017-01-07        13650             1
# 58185         584 2016-12-30 2017-01-07        26916             1
# 58186         605 2016-12-30 2017-01-07        27473             1
# 58187         538 2016-12-30 2017-01-07        27473             1
# 58188         490 2016-12-30 2017-01-07        27473             1
#
#        SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  \
# 0                      6          SO43697                     1
# ...

# %%
sns.pairplot(monthly_sales)

# %%
sns.boxplot(monthly_sales, x='Sales')

sns.swarmplot(monthly_sales, x='Sales',color='pink')
# Out:
# <Axes: xlabel='Sales'>
